# %% [markdown]
# <a href="https://colab.research.google.com/github/YJInn0121/QM2-Group17-Project/blob/main/Regression_%2B_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_excel("personal-well-being-borough.xlsx")
df.dropna(how='all', inplace=True)
df.drop(2, inplace=True)
df.drop(['Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9'], axis=1, inplace=True)
df = df.loc[:, ['Unnamed: 1','Life Satisfaction', 'Unnamed: 3', 'Unnamed: 4','Unnamed: 5']]
df.drop(df.index[35:52], inplace=True)
df.rename(columns={'Unnamed: 1': 'Area',

                   'Life Satisfaction':'Life Satisfaction 2011/2012',
                   'Unnamed: 3':'Life Satisfaction 2012/2013',
                   'Unnamed: 4':'Life Satisfaction 2013/2014',
                   'Unnamed: 5':'Life Satisfaction 2014/2015',

                   }, inplace=True)
df.drop(index=df.index[0], inplace=True)
life_satisfaction=df
life_satisfaction
# Out:
#      <input type="file" id="files-8ed3424a-955c-4ec1-a3b3-49ae2103c5eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ed3424a-955c-4ec1-a3b3-49ae2103c5eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_excel("personal-well-being-borough.xlsx")
df.dropna(how='all', inplace=True)
df.drop(2, inplace=True)
df = df.loc[:, ['Unnamed: 1','Anxiety', 'Unnamed: 30', 'Unnamed: 31','Unnamed: 32']]
df.rename(columns={'Unnamed: 1': 'Area',

                   'Anxiety':'Anxiety 2011/2012',
                   'Unnamed: 30':'Anxiety 2012/2013',
                   'Unnamed: 31':'Anxiety 2013/2014',
                   'Unnamed: 32':'Anxiety 2014/2015',

                   }, inplace=True)
df.drop(df.index[33:52], inplace=True)
df.drop(index=df.index[0], inplace=True)
life_anxiety=df
life_anxiety
# Out:
#      <input type="file" id="files-7e2178d1-4402-4ab6-936d-2118e3ea6e5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e2178d1-4402-4ab6-936d-2118e3ea6e5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#gcse results
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_excel("gcse-results-old.xls",header=1)
df.dropna(how='all', inplace=True)
df.drop(df.index[33:50], inplace=True)
df.drop('Unnamed: 8', axis=1, inplace=True)
df.drop(index=df.index[0], inplace=True)
df.rename(columns={'Unnamed: 1': 'Area',
                   'Unnamed: 3':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C including English & mathematics GCSEs',
                   'Unnamed: 4':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C including English & mathematics GCSEs',
                   'Unnamed: 5':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C including English & mathematics GCSEs',
                   'Unnamed: 6':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C including English & mathematics GCSEs',
                   'Unnamed: 7':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C including English & mathematics GCSEs',
                   'Unnamed: 10':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C grades	',
                   'Unnamed: 11':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C grades	',
                   'Unnamed: 12':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C grades	',
                   'Unnamed: 13':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C grades	',
                   'Unnamed: 14':'Percentage of pupils at the end of key stage 4 achieving 5+ A*-C grades	',
                   }, inplace=True)
df.drop(['2009/10','2010/11', '2010/11.1', '2011/12.1', '2012/13.1', '2013/14.1', '2014/15.1','2009/10.1'], axis=1, inplace=True)
df.rename(columns={'2011/12': 'Gcse results 2011/2012', '2012/13':'Gcse results 2012/2013','2013/14':'Gcse results 2013/2014','2014/15':'Gcse results 2014/2015'
                   }, inplace=True)
gcse_results=df
gcse_results
# Out:
#      <input type="file" id="files-c1c8a606-e0bd-4ef3-a758-fb5bdc382967" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1c8a606-e0bd-4ef3-a758-fb5bdc382967">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_excel("sports-participation-borough-region.xls")
df = df.drop(df.index[1:13])
df = df.drop([
              'Unnamed: 1',
              'APS1 2005/06',
              'Unnamed: 4',
              'APS2 2007/08',
              'Unnamed: 6',
              'APS3 2008/09',
              'Unnamed: 8',
              'APS4 2009/10',
              'Unnamed: 10',
              'APS5 2010/11',
              'Unnamed: 12',
              'Unnamed: 14',
              'Unnamed: 16',
              'Unnamed: 18',
              'Unnamed: 20',
              'Unnamed: 22',
              'APS10 (2015/2016'



              ], axis=1)
df.rename(columns={'Unnamed: 2':'Area',

                   'APS6 2011/12':'APS 2011/2012',
                   'APS7 2012/13':'APS 2012/2013',
                   'APS8 2013/14':'APS 2013/2014',
                   'APS9 2014/15':'APS 2014/2015',

                   }, inplace=True)
df.drop(index=df.index[0], inplace=True)
sports_participation=df
sports_participation
# Out:
#      <input type="file" id="files-7bd1e8b3-914b-4626-8da5-beb70221b17d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bd1e8b3-914b-4626-8da5-beb70221b17d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_csv("MPS Borough Level Crime.csv")
df = df.drop([
              '201004', '201005','201006','201007','201008','201009','201010','201011',
              '201101','201102','201103','201104','201105','201106','201107',
              '201012','201509','201510','201511','201512','201601','201602','201602', '201603', '201604', '201605', '201606',
              '201607', '201608', '201609', '201610', '201611', '201612', '201701', '201702',
              '201703', '201704', '201705', '201706', '201707', '201708', '201709', '201710',
              '201711', '201712', '201801', '201802', '201803', '201804', '201805', '201806', '201807',
              '201808', '201809', '201810', '201811', '201812', '201901', '201902', '201903', '201904',
              '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001',
              '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
              '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106', '202107'


              ], axis=1)
df.rename(columns={'LookUp_BoroughName': 'Area'}, inplace=True)
crime=df
crime
# Out:
#      <input type="file" id="files-5896915a-91d7-4867-a454-ab4da2acd8ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5896915a-91d7-4867-a454-ab4da2acd8ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
crime_data = crime.groupby('Area').sum()
crime_data
# Out:
# <ipython-input-47-9bf9b8c77b06>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   crime_data = crime.groupby('Area').sum()
#                                           201108  201109  201110  201111  \
# Area
# Barking and Dagenham                        1676    1411    1415    1504
# Barnet                                      2076    1965    2163    2274
# Bexley                                      1042     936     911    1037
# Brent                                       2388    2343    2795    2700
# Bromley                                     1865    1748    1800    1828
# Camden                                      2745    2840    3080    3150
# Croydon                                     2999    2528    2714    2703
# ...

# %%
crime_data['Crime 2011/2012'] = crime_data.loc[:, '201108':'201207'].sum(axis=1)
crime_data['Crime 2012/2013'] = crime_data.loc[:, '201208':'201307'].sum(axis=1)
crime_data['Crime 2013/2014'] = crime_data.loc[:, '201308':'201407'].sum(axis=1)
crime_data['Crime 2014/2015'] = crime_data.loc[:, '201408':'201507'].sum(axis=1)
print(crime_data)
# Out:
#                                           201108  201109  201110  201111  \
# Area
# Barking and Dagenham                        1676    1411    1415    1504
# Barnet                                      2076    1965    2163    2274
# Bexley                                      1042     936     911    1037
# Brent                                       2388    2343    2795    2700
# Bromley                                     1865    1748    1800    1828
# Camden                                      2745    2840    3080    3150
# Croydon                                     2999    2528    2714    2703
# Ealing                                      2885    2323    2651    2626
# Enfield                                     1984    1728    1901    1936
# Greenwich                                   1948    1672    1705    1859
# Hackney                                     2262    2272    2269    2362
# Hammersmith and Fulham                      1930    1837    1883    1967
# ...

# %%
new_data = crime_data.groupby('Area')['Crime 2011/2012','Crime 2012/2013','Crime 2013/2014','Crime 2014/2015'].sum().reset_index()
new_data
# Out:
# <ipython-input-49-d71e10cd3166>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_data = crime_data.groupby('Area')['Crime 2011/2012','Crime 2012/2013','Crime 2013/2014','Crime 2014/2015'].sum().reset_index()
#                                         Area  Crime 2011/2012  \
# 0                       Barking and Dagenham            17743
# 1                                     Barnet            25481
# 2                                     Bexley            12075
# 3                                      Brent            29525
# 4                                    Bromley            21103
# 5                                     Camden            34651
# 6                                    Croydon            32361
# 7                                     Ealing            31035
# 8                                    Enfield            22272
# ...

# %%
from google.colab import files
uploaded=files.upload()
! pip install pandas
import pandas as pd
df = pd.read_excel("residence earning.xlsx")
df.dropna(how='all', inplace=True)
pd.set_option('display.max_columns', None)
df.drop(df.index[0])
df.drop(df.index[34:52], inplace=True)
df.columns
clean = df.drop([2002,  'Unnamed: 3',
                2003,  'Unnamed: 5',          2004,  'Unnamed: 7',
                2005,  'Unnamed: 9',          2006, 'Unnamed: 11',
                2007, 'Unnamed: 13',          2008, 'Unnamed: 15',
                2009, 'Unnamed: 17',          2010, 'Unnamed: 19',
         'Unnamed: 21','Unnamed: 23','Unnamed: 25','Unnamed: 27','Unnamed: 29',
          2016, 'Unnamed: 31',
                2017, 'Unnamed: 33',          2018, 'Unnamed: 35',
                2019, 'Unnamed: 37',          2020, 'Unnamed: 39',
                2021, 'Unnamed: 41',          2022, 'Unnamed: 43'], axis=1)

for year in range(2011,2016):
  clean[year] = pd.to_numeric(clean[year], errors='coerce')
clean['income 2011/2012'] = clean[[2011, 2012]].mean(axis=1, numeric_only=True)
clean['income 2012/2013'] = clean[[2012, 2013]].mean(axis=1, numeric_only=True)
clean['income 2013/2014'] = clean[[2013, 2014]].mean(axis=1, numeric_only=True)
clean['income 2014/2015'] = clean[[2014, 2015]].mean(axis=1, numeric_only=True)
cleaned_income= clean.groupby('Area')['income 2011/2012','income 2012/2013','income 2013/2014','income 2014/2015'].mean().reset_index()
cleaned_income
# Out:
#      <input type="file" id="files-79abff54-5810-4b16-9ab8-8afc7020ac8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79abff54-5810-4b16-9ab8-8afc7020ac8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cleaned_income.drop(df.index[6])
cleaned_income
# Out:
#                       Area  income 2011/2012  income 2012/2013  \
# 0     Barking and Dagenham            451.05            445.60
# 1                   Barnet            500.70            510.30
# 2                   Bexley            507.10            503.50
# 3                    Brent            428.45            441.90
# 4                  Bromley            559.15            573.85
# 5                   Camden            612.00            620.75
# 6           City of London               NaN               NaN
# 7                  Croydon            487.45            487.30
# 8                   Ealing            490.80            498.55
# 9                  Enfield            465.60            452.85
# 10               Greenwich            479.25            493.50
# 11                 Hackney            514.40            515.20
# 12  Hammersmith and Fulham            603.70            612.00
# 13                Haringey            480.45            476.85
# ...

# %%
dfs = [life_satisfaction, life_anxiety, gcse_results, sports_participation,new_data,cleaned_income]
merged_df = dfs[0]

for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on='Area')
merged_df.drop(['Code', 'Age 16+ Sports participation - At least three times a week\n'], axis=1)
# Out:
#                       Area Life Satisfaction 2011/2012  \
# 0     Barking and Dagenham                        7.05
# 1                   Barnet                        7.43
# 2                   Bexley                        7.42
# 3                    Brent                        7.11
# 4                  Bromley                         7.5
# 5                   Camden                        7.25
# 6                  Croydon                        7.04
# 7                   Ealing                        7.22
# 8                  Enfield                        7.23
# 9                Greenwich                        7.18
# 10                 Hackney                           7
# 11  Hammersmith and Fulham                        7.38
# 12                Haringey                        7.11
# 13                  Harrow                        7.31
# 14                Havering                        7.35
# 15              Hillingdon                         7.4
# ...

# %%
sns.pairplot(merged_df[['Life Satisfaction 2011/2012', 'Anxiety 2011/2012', 'Gcse results 2011/2012', 'APS 2011/2012']], diag_kind='kde')
plt.suptitle('Pair Plot')
plt.xlabel('')
plt.xticks(rotation=90)

plt.show()

# %%
df['Life Satisfaction 2012/2013']= [
    7.09, 7.28, 7.42, 7.28, 7.60, 7.24, 7.01, 7.22, 7.24, 7.15, 7.07, 7.21, 7.17,
    7.37, 7.36, 7.37, 7.35, 7.14, 7.70, 7.17, 7.08, 7.23, 7.18, 7.23, 7.30, 7.40,
    7.21, 7.28, 7.32, 7.24, 7.26, 7.00,7.00
]
df['Life Satisfaction 2012/2013']
# Out:
# 0     7.09
# 1     7.28
# 2     7.42
# 3     7.28
# 4     7.60
# 5     7.24
# 6     7.01
# 7     7.22
# 8     7.24
# 9     7.15
# 10    7.07
# 11    7.21
# 12    7.17
# 13    7.37
# 14    7.36
# 15    7.37
# 16    7.35
# 17    7.14
# 18    7.70
# 19    7.17
# 20    7.08
# 21    7.23
# 22    7.18
# 23    7.23
# 24    7.30
# 25    7.40
# 26    7.21
# 27    7.28
# 28    7.32
# 29    7.24
# 30    7.26
# 31    7.00
# 32    7.00
# Name: Life Satisfaction 2012/2013, dtype: float64

# %%
sns.jointplot(data=merged_df, # plot a scatterplot with a regression line and two histograms
                x='income 2011/2012', # set the x axis to be the years of schooling
                y='Life Satisfaction 2011/2012', # set the y axis to be the hourly wage
                kind="reg",  # set the kind of plot to be a regression plot
                scatter_kws=dict(alpha=0.1), # set the transparency of the points to be 0.1 (10%)
                line_kws=dict(color='red'), # set the color of the regression line to red
                height=10) # set the height of the plot to be 10 inches

plt.xlabel('income in 2011/2012') # add a label to the x axis
plt.ylabel('Life satisfaction') # add a label to the y axis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-19ec99f55f73> in <cell line: 1>()
# ----> 1 sns.jointplot(data=merged_df, # plot a scatterplot with a regression line and two histograms
#       2                 x='income 2011/2012', # set the x axis to be the years of schooling
#       3                 y='Life Satisfaction 2011/2012', # set the y axis to be the hourly wage
#       4                 kind="reg",  # set the kind of plot to be a regression plot
#       5                 scatter_kws=dict(alpha=0.1), # set the transparency of the points to be 0.1 (10%)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2322
#    2323         joint_kws.setdefault("color", color)
# ...

# %%
sns.jointplot(data=merged_df, # plot a scatterplot with a regression line and two histograms
                x='income 2011/2012', # set the x axis to be the years of schooling
                y='Crime 2011/2012', # set the y axis to be the hourly wage
                kind="reg",  # set the kind of plot to be a regression plot
                scatter_kws=dict(alpha=0.1), # set the transparency of the points to be 0.1 (10%)
                line_kws=dict(color='red'), # set the color of the regression line to red
                height=10) # set the height of the plot to be 10 inches

plt.xlabel('income in 2011/2012') # add a label to the x axis
plt.ylabel('Crime 2011/2012') # add a label to the y axis
# Out:
# Text(69.75, 0.5, 'Crime 2011/2012')

# %%
print(merged_df.columns)
# Out:
# Index(['Area', 'Life Satisfaction 2011/2012', 'Life Satisfaction 2012/2013',
#        'Life Satisfaction 2013/2014', 'Life Satisfaction 2014/2015',
#        'Anxiety 2011/2012', 'Anxiety 2012/2013', 'Anxiety 2013/2014',
#        'Anxiety 2014/2015', 'Code', 'Gcse results 2011/2012',
#        'Gcse results 2012/2013', 'Gcse results 2013/2014',
#        'Gcse results 2014/2015',
#        'Age 16+ Sports participation - At least three times a week\n',
#        'APS 2011/2012', 'APS 2012/2013', 'APS 2013/2014', 'APS 2014/2015',
#        'Crime 2011/2012', 'Crime 2012/2013', 'Crime 2013/2014',
#        'Crime 2014/2015', 'income 2011/2012', 'income 2012/2013',
#        'income 2013/2014', 'income 2014/2015'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.api as sm
from math import sqrt
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from scipy.stats import sem
import statistics
import seaborn as sns
from IPython.display import display, Math, Latex, display_latex
import plotly.express as px
import pylab
import pandas as pd
import numpy as np
# make the plots (graphs) a little wider by default
pylab.rcParams['figure.figsize'] = (10., 8.)
sns.set(font_scale=1.5)
sns.set_style("white")

# %%
# Make sure to use the exact column names as they appear in the DataFrame
first_year = ['Area','Life Satisfaction 2011/2012','Anxiety 2011/2012','Gcse results 2011/2012','APS 2011/2012','Crime 2011/2012','income 2011/2012']

new_df1 = merged_df[first_year]
summary1 = new_df1.describe(include='all')
summary1
# Out:
#                         Area  Life Satisfaction 2011/2012  Anxiety 2011/2012  \
# count                     32                        32.00               32.0
# unique                    32                        27.00               29.0
# top     Barking and Dagenham                         7.33                3.3
# freq                       1                         3.00                3.0
# mean                     NaN                          NaN                NaN
# std                      NaN                          NaN                NaN
# min                      NaN                          NaN                NaN
# 25%                      NaN                          NaN                NaN
# 50%                      NaN                          NaN                NaN
# 75%                      NaN                          NaN                NaN
# max                      NaN                          NaN                NaN
#
# ...

# %%
sns.heatmap(summary1.corr(), # plot a correlation matrix
            annot=True, # show the correlation values on the plot
            fmt=".2f", # set the format of the correlation values to be two decimal places
            cmap='coolwarm') # set the color palette to be coolwarm (blue for negative correlations, red for positive correlations)

plt.title('Correlation Matrix') # add a title
# Out:
# <ipython-input-17-1137c63e8e6a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(summary1.corr(), # plot a correlation matrix
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Make sure to use the exact column names as they appear in the DataFrame
second_year = ['Area','Life Satisfaction 2012/2013','Anxiety 2012/2013','Gcse results 2012/2013','APS 2012/2013','Crime 2012/2013','income 2012/2013']

new_df2 = merged_df[second_year]
summary2 = new_df2.describe(include='all')
summary2
# Out:
#                         Area  Life Satisfaction 2012/2013  Anxiety 2012/2013  \
# count                     32                        32.00              32.00
# unique                    32                        24.00              27.00
# top     Barking and Dagenham                         7.24               3.66
# freq                       1                         3.00               3.00
# mean                     NaN                          NaN                NaN
# std                      NaN                          NaN                NaN
# min                      NaN                          NaN                NaN
# 25%                      NaN                          NaN                NaN
# 50%                      NaN                          NaN                NaN
# 75%                      NaN                          NaN                NaN
# max                      NaN                          NaN                NaN
#
# ...

# %%
sns.heatmap(summary2.corr(), # plot a correlation matrix
            annot=True, # show the correlation values on the plot
            fmt=".2f", # set the format of the correlation values to be two decimal places
            cmap='coolwarm') # set the color palette to be coolwarm (blue for negative correlations, red for positive correlations)

plt.title('Correlation Matrix') # add a title
# Out:
# <ipython-input-20-29d763d16ff1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(summary2.corr(), # plot a correlation matrix
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Make sure to use the exact column names as they appear in the DataFrame
third_year = ['Area','Life Satisfaction 2013/2014','Anxiety 2013/2014','Gcse results 2013/2014','APS 2013/2014','Crime 2013/2014','income 2013/2014']

new_df3 = merged_df[third_year]
summary3 = new_df3.describe(include='all')
summary3
# Out:
#                         Area  Life Satisfaction 2013/2014  Anxiety 2013/2014  \
# count                     32                        32.00              32.00
# unique                    32                        21.00              28.00
# top     Barking and Dagenham                         7.28               3.07
# freq                       1                         3.00               2.00
# mean                     NaN                          NaN                NaN
# std                      NaN                          NaN                NaN
# min                      NaN                          NaN                NaN
# 25%                      NaN                          NaN                NaN
# 50%                      NaN                          NaN                NaN
# 75%                      NaN                          NaN                NaN
# max                      NaN                          NaN                NaN
#
# ...

# %%
sns.heatmap(summary3.corr(), # plot a correlation matrix
            annot=True, # show the correlation values on the plot
            fmt=".2f", # set the format of the correlation values to be two decimal places
            cmap='coolwarm') # set the color palette to be coolwarm (blue for negative correlations, red for positive correlations)

plt.title('Correlation Matrix') # add a title
# Out:
# <ipython-input-58-6f8191d05d7e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(summary3.corr(), # plot a correlation matrix
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Make sure to use the exact column names as they appear in the DataFrame
fourth_year = ['Area','Life Satisfaction 2014/2015','Anxiety 2014/2015','Gcse results 2014/2015','APS 2014/2015','Crime 2014/2015','income 2014/2015']

new_df4 = merged_df[fourth_year]
summary4 = new_df4.describe(include='all')
summary4
# Out:
#                         Area  Life Satisfaction 2014/2015  Anxiety 2014/2015  \
# count                     32                        32.00              32.00
# unique                    32                        23.00              29.00
# top     Barking and Dagenham                         7.54               3.02
# freq                       1                         4.00               2.00
# mean                     NaN                          NaN                NaN
# std                      NaN                          NaN                NaN
# min                      NaN                          NaN                NaN
# 25%                      NaN                          NaN                NaN
# 50%                      NaN                          NaN                NaN
# 75%                      NaN                          NaN                NaN
# max                      NaN                          NaN                NaN
#
# ...

# %%
sns.heatmap(summary4.corr(), # plot a correlation matrix
            annot=True, # show the correlation values on the plot
            fmt=".2f", # set the format of the correlation values to be two decimal places
            cmap='coolwarm') # set the color palette to be coolwarm (blue for negative correlations, red for positive correlations)

plt.title('Correlation Matrix') # add a title
# Out:
# <ipython-input-80-62e79268a19c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(summary4.corr(), # plot a correlation matrix
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
fourth_year = ['Area','Life Satisfaction 2014/2015','Anxiety 2014/2015','Gcse results 2014/2015','APS 2014/2015','Crime 2014/2015','income 2014/2015']
new_df4 = merged_df[fourth_year]

# %%
import pandas as pd
from statsmodels.formula.api import ols

new_df1['Life Satisfaction 2011/2012'] = pd.to_numeric(new_df1['Life Satisfaction 2011/2012'], errors='coerce')

formula = 'Q("Life Satisfaction 2011/2012") ~ Q("Anxiety 2011/2012") + Q("Gcse results 2011/2012") + Q("APS 2011/2012") + Q("Crime 2011/2012") + Q("income 2011/2012")'


model = ols(formula, data=new_df1).fit()

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-13f062a7e929> in <cell line: 4>()
#       2 from statsmodels.formula.api import ols
#       3
# ----> 4 new_df1['Life Satisfaction 2011/2012'] = pd.to_numeric(new_df1['Life Satisfaction 2011/2012'], errors='coerce')
#       5
#       6 formula = 'Q("Life Satisfaction 2011/2012") ~ Q("Anxiety 2011/2012") + Q("Gcse results 2011/2012") + Q("APS 2011/2012") + Q("Crime 2011/2012") + Q("income 2011/2012")'
#
# NameError: name 'new_df1' is not defined

# %%
sns.barplot(data=merged_df, x='Area', y='income 2011/2012') # plot the union variable

plt.title('Income') # add a title
plt.xlabel('') # remove the x axis label
plt.xticks(rotation=90) # replace the x axis labels with more descriptive labels
plt.show() # show the plot

# %%
sns.barplot(data=merged_df, x='Area', y='Anxiety 2011/2012') # plot the union variable

plt.title('Anxiety') # add a title
plt.xlabel('') # remove the x axis label
plt.xticks(rotation=90) # replace the x axis labels with more descriptive labels
plt.show() # show the plot

# %%
sns.barplot(data=merged_df, x='Area', y='Life Satisfaction 2011/2012') # plot the union variable

plt.title('Life Satisfaction 2011/2012') # add a title
plt.xlabel('') # remove the x axis label
plt.xticks(rotation=90) # replace the x axis labels with more descriptive labels
plt.show() # show the plot

# %%
sns.barplot(data=merged_df, x='Area', y='APS 2011/2012') # plot the union variable

plt.title('APS 2011/2012') # add a title
plt.xlabel('') # remove the x axis label
plt.xticks(rotation=90) # replace the x axis labels with more descriptive labels
plt.show() # show the plot

# %%
sns.barplot(data=merged_df, x='Area', y='Gcse results 2011/2012') # plot the union variable

plt.title('Gcse results') # add a title
plt.xlabel('') # remove the x axis label
plt.xticks(rotation=90) # replace the x axis labels with more descriptive labels
plt.show() # show the plot

# %%
first_year = ['Area','Life Satisfaction 2011/2012','Anxiety 2011/2012','Gcse results 2011/2012','APS 2011/2012','Crime 2011/2012','income 2011/2012']
new_df1 = merged_df[first_year]

# %%
import pandas as pd
from statsmodels.formula.api import ols

new_df1['Life Satisfaction 2011/2012'] = pd.to_numeric(new_df1['Life Satisfaction 2011/2012'], errors='coerce')

formula = 'Q("Life Satisfaction 2011/2012") ~ Q("Anxiety 2011/2012") + Q("Gcse results 2011/2012") + Q("APS 2011/2012") + Q("Crime 2011/2012") + Q("income 2011/2012")'

model = ols(formula, data=new_df1).fit()

print(model.summary())
# Out:
# <ipython-input-76-928bfe13f9ae>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df1['Life Satisfaction 2011/2012'] = pd.to_numeric(new_df1['Life Satisfaction 2011/2012'], errors='coerce')
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# ...

# %%
second_year = ['Area','Life Satisfaction 2012/2013','Anxiety 2012/2013','Gcse results 2012/2013','APS 2012/2013','Crime 2012/2013','income 2012/2013']
new_df2 = merged_df[second_year]

# %%
import pandas as pd
from statsmodels.formula.api import ols
new_df2['Life Satisfaction 2012/2013'] = pd.to_numeric(new_df2['Life Satisfaction 2012/2013'], errors='coerce')

formula = 'Q("Life Satisfaction 2012/2013") ~ Q("Anxiety 2012/2013") + Q("Gcse results 2012/2013") + Q("APS 2012/2013") + Q("Crime 2012/2013") + Q("income 2012/2013")'


model = ols(formula, data=new_df2).fit()

# Display the summary
print(model.summary())

#I made the dependent variable is Life Satisfaction, the rest are independent variables
#I used the Q() function from the statsmodels library to handle the variables with spaces and special characters in their names. - thats why some varbiables werent printing
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Q("Life Satisfaction 2012/2013")   R-squared:                       1.000
# Model:                                          OLS   Adj. R-squared:                    nan
# Method:                               Least Squares   F-statistic:                       nan
# Date:                              Tue, 16 Jan 2024   Prob (F-statistic):                nan
# Time:                                      16:00:46   Log-Likelihood:                 816.92
# No. Observations:                                32   AIC:                            -1570.
# Df Residuals:                                     0   BIC:                            -1523.
# Df Model:                                        31
# Covariance Type:                          nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
third_year = ['Area','Life Satisfaction 2013/2014','Anxiety 2013/2014','Gcse results 2013/2014','APS 2013/2014','Crime 2013/2014','income 2013/2014']
new_df3 = merged_df[third_year]

# %%
import pandas as pd
from statsmodels.formula.api import ols

new_df3['Life Satisfaction 2013/2014'] = pd.to_numeric(new_df3['Life Satisfaction 2013/2014'], errors='coerce')

formula = 'Q("Life Satisfaction 2013/2014") ~ Q("Anxiety 2013/2014") + Q("Gcse results 2013/2014") + Q("APS 2013/2014") + Q("Crime 2013/2014") + Q("income 2013/2014")'

model = ols(formula, data=new_df3).fit()

print(model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Q("Life Satisfaction 2013/2014")   R-squared:                       1.000
# Model:                                          OLS   Adj. R-squared:                    nan
# Method:                               Least Squares   F-statistic:                       nan
# Date:                              Mon, 08 Jan 2024   Prob (F-statistic):                nan
# Time:                                      20:13:27   Log-Likelihood:                 805.76
# No. Observations:                                32   AIC:                            -1548.
# Df Residuals:                                     0   BIC:                            -1501.
# Df Model:                                        31
# Covariance Type:                          nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
fourth_year = ['Area','Life Satisfaction 2014/2015','Anxiety 2014/2015','Gcse results 2014/2015','APS 2014/2015','Crime 2014/2015','income 2014/2015']
new_df4 = merged_df[fourth_year]

# %%
import pandas as pd
from statsmodels.formula.api import ols

new_df4['Life Satisfaction 2014/2015'] = pd.to_numeric(new_df4['Life Satisfaction 2014/2015'], errors='coerce')

formula = 'Q("Life Satisfaction 2014/2015") ~ Q("Anxiety 2014/2015") + Q("Gcse results 2014/2015") + Q("APS 2014/2015") + Q("Crime 2014/2015") + Q("income 2014/2015")'

model = ols(formula, data=new_df4).fit()

print(model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Q("Life Satisfaction 2014/2015")   R-squared:                       1.000
# Model:                                          OLS   Adj. R-squared:                    nan
# Method:                               Least Squares   F-statistic:                       nan
# Date:                              Mon, 08 Jan 2024   Prob (F-statistic):                nan
# Time:                                      20:16:07   Log-Likelihood:                 811.49
# No. Observations:                                32   AIC:                            -1559.
# Df Residuals:                                     0   BIC:                            -1512.
# Df Model:                                        31
# Covariance Type:                          nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# ...
